# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gp

# %%
listingDF = pd.read_csv('data/listings.csv')

# %%
neighbourhood = gp.read_file('data/neighbourhoods.geojson')
neighbourhood.plot(column='neighbourhood_group')
# Out:
# <Axes: >

# %%
#f = open('data/listings.info', 'w+')
#listingDF.info(verbose=True, buf=f)
#f.close()
